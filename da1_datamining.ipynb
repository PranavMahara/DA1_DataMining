# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_csv('/content/employee_da1.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **1. Get the dimensions, structure, attribute names, and attribute values of the dataset**

# %%
# Dimensions are given by shape
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (30, 6)

# %%
# Structure of the dataframe is given by info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Empid        30 non-null     int64
#  1   Name         30 non-null     object
#  2   Designation  30 non-null     object
#  3   Salary       30 non-null     int64
#  4   Experience   30 non-null     int64
#  5   Vaccinated   30 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 1.5+ KB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Attribute names is given by using columns
df.columns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['Empid', 'Name', 'Designation', 'Salary', 'Experience', 'Vaccinated'], dtype='object')

# %%
# Attribute values of the dataset is given by using head() that gives the values of top 5 attributes
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Empid     Name Designation  Salary  Experience Vaccinated
# 0      1   Pranav     Manager   30000          10        Yes
# 1      2  Abhinav       Clerk   18000           6        Yes
# 2      3     Arya      Labour    8000           2        Yes
# 3      4    Aditi      Labour    9000           3         No
# 4      5    Rahul  Supervisor   22000           8        Yes

# %% [markdown]
# # **2. Display**

# %%
# (A) First 5 Records
# got by using head(5) which giues the top 5 records
df.head(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    Empid     Name Designation  Salary  Experience Vaccinated
# 0      1   Pranav     Manager   30000          10        Yes
# 1      2  Abhinav       Clerk   18000           6        Yes
# 2      3     Arya      Labour    8000           2        Yes
# 3      4    Aditi      Labour    9000           3         No
# 4      5    Rahul  Supervisor   22000           8        Yes

# %%
# (B) Last 5 Records
# got by using tail(5) which giues the last 5 records
df.tail(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Empid     Name Designation  Salary  Experience Vaccinated
# 25     26    Tarun      Labour   10000           2         No
# 26     27   Ishita       Clerk   17000           5        Yes
# 27     28    Eshan      Labour   16000           4         No
# 28     29  Samatha     Manager   22000           8        Yes
# 29     30   Jayesh       Clerk   20000           6        Yes

# %%
# (C) Name, Designation, Salary of First 10 records
# got using loc that helps us only retrieve the entries from location 0-9
# we also specify the Columns of the first 10 entries that we wish to see
df.loc[:9, ["Name", "Designation", "Salary"]]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#       Name Designation  Salary
# 0   Pranav     Manager   30000
# 1  Abhinav       Clerk   18000
# 2     Arya      Labour    8000
# 3    Aditi      Labour    9000
# 4    Rahul  Supervisor   22000
# 5   Shanti  Supervisor   24000
# 6    Omkar      Labour   10000
# 7      Ram      Labour   16000
# 8  Krishna       Clerk   18000
# 9   Khushi  Supervisor   20000

# %%
# (D) Name of all records
df["Name"]
# this gives us the value in Name column of all the entries
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0       Pranav
# 1      Abhinav
# 2         Arya
# 3        Aditi
# 4        Rahul
# 5       Shanti
# 6        Omkar
# 7          Ram
# 8      Krishna
# 9       Khushi
# 10    Harshita
# 11       Karun
# 12        Ravi
# 13      Rashmi
# 14     Praveen
# 15       Smiti
# 16    Prakriti
# 17      Ramesh
# 18        Hiba
# 19        Jose
# 20     Anthony
# 21        John
# 22       Beena
# 23     Prakash
# 24      Samuel
# 25       Tarun
# 26      Ishita
# 27       Eshan
# 28     Samatha
# 29      Jayesh
# Name: Name, dtype: object

# %%
# (E) All records
# variable which stores the datafram will give all its records
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Empid      Name Designation  Salary  Experience Vaccinated
# 0       1    Pranav     Manager   30000          10        Yes
# 1       2   Abhinav       Clerk   18000           6        Yes
# 2       3      Arya      Labour    8000           2        Yes
# 3       4     Aditi      Labour    9000           3         No
# 4       5     Rahul  Supervisor   22000           8        Yes
# 5       6    Shanti  Supervisor   24000           9         No
# 6       7     Omkar      Labour   10000           3        Yes
# 7       8       Ram      Labour   16000           4         No
# ...

# %% [markdown]
# # **3. Display the following statistical measures of the dataset**

# %%
# a) Mean, median and mode of the variables
# mean using mean()
# applying it only on the columns with numeric entries
df.mean(numeric_only=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empid            15.500000
# Salary        17333.333333
# Experience        5.600000
# dtype: float64

# %%
# median using median()
# applying it only on the columns with numeric entries
df.median(numeric_only=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empid            15.5
# Salary        17500.0
# Experience        5.0
# dtype: float64

# %%
# mode using mode()
# applying it on all columns as mode can be calculated even with columns that have categorical values
df.mode().iloc[0]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empid                1
# Name           Abhinav
# Designation     Labour
# Salary         10000.0
# Experience         2.0
# Vaccinated         Yes
# Name: 0, dtype: object

# %%
# b) Variance and Covariance
# Variance using var() applying it only on numeric columns
df.var(numeric_only=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Empid         7.750000e+01
# Salary        5.243678e+07
# Experience    9.972414e+00
# dtype: float64

# %%
# Covariance using cov() applying it only on numeric columns
df.cov(numeric_only=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#                   Empid        Salary    Experience
# Empid         77.500000 -2.068966e+03     -2.206897
# Salary     -2068.965517  5.243678e+07  22448.275862
# Experience    -2.206897  2.244828e+04      9.972414

# %%
# c) Correlation of salary to experience
# got by applying corr() between the two columns
df["Salary"].corr(df["Experience"])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 0.9816684449993734

# %% [markdown]
# # **4. Draw the following**

# %%
# A) Pie chart on designation
plt.figure(figsize=(4,4))
des_count = df["Designation"].value_counts() # stores the counts of each designation
plt.pie(des_count, labels=des_count.index, autopct='%1.2f%%')
plt.title("Pie Chart of Designation")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# B) Histogram of Salary
plt.figure(figsize=(5, 5))
plt.hist(df["Salary"], bins=10, color='blue', edgecolor='black')
plt.title("Histogram of Salary")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# C) Scatter plot of Salary to Experience
plt.figure(figsize=(5, 5))
plt.scatter(df["Salary"], df["Experience"], color='blue')
plt.title("Scatter Plot of Salary to Experience")
plt.xlabel("Salary")
plt.ylabel("Experience")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **Question - 2**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_csv('/content/oil-prices_da1.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         Month  Consumer Price Index (1982-84=1)  \
# 0  01-01-1999                              1.65
# 1  01-02-1999                              1.65
# 2  01-03-1999                              1.65
# 3  01-04-1999                              1.66
# 4  01-05-1999                              1.66
#
#    Motor Gasoline Price ($/gallon) Nominal  \
# 0                                     0.94
# 1                                     0.92
# 2                                     0.98
# 3                                     1.13
# 4                                     1.13
#
#     Motor Gasoline Price ($/gallon) Real
# ...

# %%
df.columns
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Index(['Month', 'Consumer Price Index (1982-84=1)',
#        'Motor Gasoline Price ($/gallon) Nominal',
#        ' Motor Gasoline Price ($/gallon) Real'],
#       dtype='object')

# %%
# Consumer Price Index (1982-84=1) vs Motor Gasoline Price ($/gallon) Nominal
df.columns = ['Month', 'Consumer Price Index (1982-84=1)',
       'Motor Gasoline Price ($/gallon) Nominal',
       ' Motor Gasoline Price ($/gallon) Real']
from matplotlib import pyplot as plt
df.plot(kind='scatter', x='Consumer Price Index (1982-84=1)', y=' Motor Gasoline Price ($/gallon) Real', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.columns = ['Month', 'Consumer Price Index (1982-84=1)',
       'Motor Gasoline Price ($/gallon) Nominal',
       ' Motor Gasoline Price ($/gallon) Real']
from matplotlib import pyplot as plt
df['Consumer Price Index (1982-84=1)'].plot(kind='line', figsize=(8, 4), title='Variation of Consumer Price Index')
plt.gca().spines[['top', 'right']].set_visible(False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.columns = ['date','CPI','nominal price','real price']
data = df['real price'].dropna()

num_bins = 20
mean, std_dev = np.mean(data), np.std(data)

plt.figure(figsize=(6, 6))
plt.hist(data, bins=num_bins, color='red', edgecolor='black', density=True)

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std_dev)

plt.plot(x, p, 'black', linewidth=2)
plt.title('Distribution of Real Gas Prices with Bell Curve')
plt.xlabel('Real Gas Price in Dollars')
plt.ylabel('Frequency')

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.columns = ['date', 'nominal_price', 'real_price', 'cpi']
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')

df.set_index('date', inplace=True)

window_size = 12
df['rolling_avg_real_price'] = df['real_price'].rolling(window=window_size).mean()


plt.figure(figsize=(12, 6))
plt.plot(df.index, df['real_price'], label='Real Gas Price', color='blue', alpha=0.7)
plt.plot(df.index, df['rolling_avg_real_price'], label=f'{window_size}-Month Rolling Average', color='red', linestyle='--')
plt.title('Real Gas Prices with Rolling Average')
plt.xlabel('Date')
plt.ylabel('Real Gas Price in Dollars')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **Question - 3**

# %%
from mlxtend.frequent_patterns import apriori, association_rules

df = pd.read_csv('/content/juicestall_da1.csv')

frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

print("Frequent Itemsets are : \n", frequent_itemsets)
print("Association Rules for the dataset is : \n", rules)
# Out:
# Frequent Itemsets are :
#       support             itemsets
# 0   0.583333             (Banana)
# 1   0.583333              (Apple)
# 2   0.583333             (Orange)
# 3   0.583333              (Mango)
# 4   0.416667             (Grapes)
# 5   0.500000          (Pineapple)
# 6   0.500000         (Watermelon)
# 7   0.416667            (Berries)
# 8   0.500000              (Lemon)
# 9   0.416667      (Banana, Apple)
# 10  0.416667      (Mango, Banana)
# 11  0.416667       (Apple, Lemon)
# 12  0.416667  (Pineapple, Orange)
# Association Rules for the dataset is :
#     antecedents  consequents  antecedent support  consequent support   support  \
# 0     (Banana)      (Apple)            0.583333            0.583333  0.416667
# 1      (Apple)     (Banana)            0.583333            0.583333  0.416667
# 2      (Mango)     (Banana)            0.583333            0.583333  0.416667
# 3     (Banana)      (Mango)            0.583333            0.583333  0.416667
# ...

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# # **Question - 4**

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules

df = pd.read_csv('/content/automobile_showroom_da1.csv')

frequent_itemsets = fpgrowth(df, min_support=0.4, use_colnames=True)

rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

print("Frequent Itemsets :\n", frequent_itemsets)
print("Association Rules :\n", rules)
# Out:
# Frequent Itemsets :
#       support                  itemsets
# 0   0.666667                     (SUV)
# 1   0.583333            (Electric Car)
# 2   0.583333                   (Sedan)
# 3   0.500000                     (Van)
# 4   0.666667               (Motorbike)
# 5   0.583333               (Hatchback)
# 6   0.583333             (Convertible)
# 7   0.500000                   (Truck)
# 8   0.416667          (Motorbike, SUV)
# 9   0.416667       (SUV, Electric Car)
# 10  0.416667       (Electric Car, Van)
# 11  0.416667    (Hatchback, Motorbike)
# 12  0.500000  (Convertible, Motorbike)
# 13  0.416667        (Hatchback, Truck)
# Association Rules :
#        antecedents     consequents  antecedent support  consequent support  \
# 0           (SUV)  (Electric Car)            0.666667            0.583333
# 1  (Electric Car)           (SUV)            0.583333            0.666667
# 2  (Electric Car)           (Van)            0.583333            0.500000
# ...

# %%
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
